# %% [markdown]
# **TASK-5=CAR PRICE PREDICTION**
#
# **AUTHOR=KUHELI DEY**
#
# **BATCH=APRIL**
#
# **DOMAIN=DATA SCIENCE**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.tree import DecisionTreeRegressor
from sklearn import metrics

# %%
# loading the data from csv file to pandas dataframe
df = pd.read_csv(r"/content/CarPrice_Assignment.csv")

# %%
# inspecting the first 5 rows of the dataframe
df.head()
# Out:
#    car_ID  symboling                   CarName fueltype aspiration doornumber  \
# 0       1          3        alfa-romero giulia      gas        std        two
# 1       2          3       alfa-romero stelvio      gas        std        two
# 2       3          1  alfa-romero Quadrifoglio      gas        std        two
# 3       4          2               audi 100 ls      gas        std       four
# 4       5          2                audi 100ls      gas        std       four
#
#        carbody drivewheel enginelocation  wheelbase  ...  enginesize  \
# 0  convertible        rwd          front       88.6  ...         130
# 1  convertible        rwd          front       88.6  ...         130
# 2    hatchback        rwd          front       94.5  ...         152
# 3        sedan        fwd          front       99.8  ...         109
# 4        sedan        4wd          front       99.4  ...         136
#
#    fuelsystem  boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 0        mpfi       3.47    2.68              9.0        111     5000      21
# 1        mpfi       3.47    2.68              9.0        111     5000      21
# 2        mpfi       2.68    3.47              9.0        154     5000      19
# 3        mpfi       3.19    3.40             10.0        102     5500      24
# 4        mpfi       3.19    3.40              8.0        115     5500      18
#
#    highwaympg    price
# 0          27  13495.0
# 1          27  16500.0
# 2          26  16500.0
# 3          30  13950.0
# 4          22  17450.0
#
# [5 rows x 26 columns]

# %%
df.tail()
# Out:
#      car_ID  symboling          CarName fueltype aspiration doornumber  \
# 200     201         -1  volvo 145e (sw)      gas        std       four
# 201     202         -1      volvo 144ea      gas      turbo       four
# 202     203         -1      volvo 244dl      gas        std       four
# 203     204         -1        volvo 246   diesel      turbo       four
# 204     205         -1      volvo 264gl      gas      turbo       four
#
#     carbody drivewheel enginelocation  wheelbase  ...  enginesize  fuelsystem  \
# 200   sedan        rwd          front      109.1  ...         141        mpfi
# 201   sedan        rwd          front      109.1  ...         141        mpfi
# 202   sedan        rwd          front      109.1  ...         173        mpfi
# 203   sedan        rwd          front      109.1  ...         145         idi
# 204   sedan        rwd          front      109.1  ...         141        mpfi
#
#      boreratio  stroke compressionratio horsepower  peakrpm citympg  \
# 200       3.78    3.15              9.5        114     5400      23
# 201       3.78    3.15              8.7        160     5300      19
# 202       3.58    2.87              8.8        134     5500      18
# 203       3.01    3.40             23.0        106     4800      26
# 204       3.78    3.15              9.5        114     5400      19
#
#      highwaympg    price
# 200          28  16845.0
# 201          25  19045.0
# 202          23  21485.0
# 203          27  22470.0
# 204          25  22625.0
#
# [5 rows x 26 columns]

# %%
df.describe()
# Out:
#            car_ID   symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000  205.000000
# mean   103.000000    0.834146   98.756585  174.049268   65.907805   53.724878
# std     59.322565    1.245307    6.021776   12.337289    2.145204    2.443522
# min      1.000000   -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%     52.000000    0.000000   94.500000  166.300000   64.100000   52.000000
# 50%    103.000000    1.000000   97.000000  173.200000   65.500000   54.100000
# 75%    154.000000    2.000000  102.400000  183.100000   66.900000   55.500000
# max    205.000000    3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.580000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower      peakrpm     citympg  highwaympg         price
# count  205.000000   205.000000  205.000000  205.000000    205.000000
# mean   104.117073  5125.121951   25.219512   30.751220  13276.710571
# std     39.544167   476.985643    6.542142    6.886443   7988.852332
# min     48.000000  4150.000000   13.000000   16.000000   5118.000000
# 25%     70.000000  4800.000000   19.000000   25.000000   7788.000000
# 50%     95.000000  5200.000000   24.000000   30.000000  10295.000000
# 75%    116.000000  5500.000000   30.000000   34.000000  16503.000000
# max    288.000000  6600.000000   49.000000   54.000000  45400.000000

# %%
# getting some information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 205 entries, 0 to 204
# Data columns (total 26 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   car_ID            205 non-null    int64
#  1   symboling         205 non-null    int64
#  2   CarName           205 non-null    object
#  3   fueltype          205 non-null    object
#  4   aspiration        205 non-null    object
#  5   doornumber        205 non-null    object
#  6   carbody           205 non-null    object
#  7   drivewheel        205 non-null    object
#  8   enginelocation    205 non-null    object
#  9   wheelbase         205 non-null    float64
#  10  carlength         205 non-null    float64
#  11  carwidth          205 non-null    float64
#  12  carheight         205 non-null    float64
#  13  curbweight        205 non-null    int64
#  14  enginetype        205 non-null    object
#  15  cylindernumber    205 non-null    object
#  16  enginesize        205 non-null    int64
#  17  fuelsystem        205 non-null    object
#  18  boreratio         205 non-null    float64
#  19  stroke            205 non-null    float64
#  20  compressionratio  205 non-null    float64
#  21  horsepower        205 non-null    int64
#  22  peakrpm           205 non-null    int64
#  23  citympg           205 non-null    int64
#  24  highwaympg        205 non-null    int64
#  25  price             205 non-null    float64
# dtypes: float64(8), int64(8), object(10)
# memory usage: 41.8+ KB

# %%
# checking the number of missing values
df.isnull().sum()
# Out:
# car_ID              0
# symboling           0
# CarName             0
# fueltype            0
# aspiration          0
# doornumber          0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# fuelsystem          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# peakrpm             0
# citympg             0
# highwaympg          0
# price               0
# dtype: int64

# %%
sns.set_style("whitegrid")
plt.figure(figsize=(15,7))
sns.histplot(df.price,kde=True,color='green')
plt.show()

# %%
df.dtypes
# Out:
# car_ID                int64
# symboling             int64
# CarName              object
# fueltype             object
# aspiration           object
# doornumber           object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# fuelsystem           object
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# peakrpm               int64
# citympg               int64
# highwaympg            int64
# price               float64
# dtype: object

# %%
for column in df.columns:
    if df[column].dtype == 'object':
        df[column] = pd.to_numeric(df[column], errors='coerce')

# %%
df.corr()
# Out:
#                     car_ID  symboling  CarName  fueltype  aspiration  \
# car_ID            1.000000  -0.151621      NaN       NaN         NaN
# symboling        -0.151621   1.000000      NaN       NaN         NaN
# CarName                NaN        NaN      NaN       NaN         NaN
# fueltype               NaN        NaN      NaN       NaN         NaN
# aspiration             NaN        NaN      NaN       NaN         NaN
# doornumber             NaN        NaN      NaN       NaN         NaN
# carbody                NaN        NaN      NaN       NaN         NaN
# drivewheel             NaN        NaN      NaN       NaN         NaN
# enginelocation         NaN        NaN      NaN       NaN         NaN
# wheelbase         0.129729  -0.531954      NaN       NaN         NaN
# carlength         0.170636  -0.357612      NaN       NaN         NaN
# carwidth          0.052387  -0.232919      NaN       NaN         NaN
# carheight         0.255960  -0.541038      NaN       NaN         NaN
# curbweight        0.071962  -0.227691      NaN       NaN         NaN
# enginetype             NaN        NaN      NaN       NaN         NaN
# cylindernumber         NaN        NaN      NaN       NaN         NaN
# enginesize       -0.033930  -0.105790      NaN       NaN         NaN
# fuelsystem             NaN        NaN      NaN       NaN         NaN
# boreratio         0.260064  -0.130051      NaN       NaN         NaN
# stroke           -0.160824  -0.008735      NaN       NaN         NaN
# compressionratio  0.150276  -0.178515      NaN       NaN         NaN
# horsepower       -0.015006   0.070873      NaN       NaN         NaN
# peakrpm          -0.203789   0.273606      NaN       NaN         NaN
# citympg           0.015940  -0.035823      NaN       NaN         NaN
# highwaympg        0.011255   0.034606      NaN       NaN         NaN
# price            -0.109093  -0.079978      NaN       NaN         NaN
#
#                   doornumber  carbody  drivewheel  enginelocation  wheelbase  \
# car_ID                   NaN      NaN         NaN             NaN   0.129729
# symboling                NaN      NaN         NaN             NaN  -0.531954
# CarName                  NaN      NaN         NaN             NaN        NaN
# fueltype                 NaN      NaN         NaN             NaN        NaN
# aspiration               NaN      NaN         NaN             NaN        NaN
# doornumber               NaN      NaN         NaN             NaN        NaN
# carbody                  NaN      NaN         NaN             NaN        NaN
# drivewheel               NaN      NaN         NaN             NaN        NaN
# enginelocation           NaN      NaN         NaN             NaN        NaN
# wheelbase                NaN      NaN         NaN             NaN   1.000000
# carlength                NaN      NaN         NaN             NaN   0.874587
# carwidth                 NaN      NaN         NaN             NaN   0.795144
# carheight                NaN      NaN         NaN             NaN   0.589435
# curbweight               NaN      NaN         NaN             NaN   0.776386
# enginetype               NaN      NaN         NaN             NaN        NaN
# cylindernumber           NaN      NaN         NaN             NaN        NaN
# enginesize               NaN      NaN         NaN             NaN   0.569329
# fuelsystem               NaN      NaN         NaN             NaN        NaN
# boreratio                NaN      NaN         NaN             NaN   0.488750
# stroke                   NaN      NaN         NaN             NaN   0.160959
# compressionratio         NaN      NaN         NaN             NaN   0.249786
# horsepower               NaN      NaN         NaN             NaN   0.353294
# peakrpm                  NaN      NaN         NaN             NaN  -0.360469
# citympg                  NaN      NaN         NaN             NaN  -0.470414
# highwaympg               NaN      NaN         NaN             NaN  -0.544082
# price                    NaN      NaN         NaN             NaN   0.577816
#
#                   ...  enginesize  fuelsystem  boreratio    stroke  \
# car_ID            ...   -0.033930         NaN   0.260064 -0.160824
# symboling         ...   -0.105790         NaN  -0.130051 -0.008735
# CarName           ...         NaN         NaN        NaN       NaN
# fueltype          ...         NaN         NaN        NaN       NaN
# aspiration        ...         NaN         NaN        NaN       NaN
# doornumber        ...         NaN         NaN        NaN       NaN
# carbody           ...         NaN         NaN        NaN       NaN
# drivewheel        ...         NaN         NaN        NaN       NaN
# enginelocation    ...         NaN         NaN        NaN       NaN
# wheelbase         ...    0.569329         NaN   0.488750  0.160959
# carlength         ...    0.683360         NaN   0.606454  0.129533
# carwidth          ...    0.735433         NaN   0.559150  0.182942
# carheight         ...    0.067149         NaN   0.171071 -0.055307
# curbweight        ...    0.850594         NaN   0.648480  0.168790
# enginetype        ...         NaN         NaN        NaN       NaN
# cylindernumber    ...         NaN         NaN        NaN       NaN
# enginesize        ...    1.000000         NaN   0.583774  0.203129
# fuelsystem        ...         NaN         NaN        NaN       NaN
# boreratio         ...    0.583774         NaN   1.000000 -0.055909
# stroke            ...    0.203129         NaN  -0.055909  1.000000
# compressionratio  ...    0.028971         NaN   0.005197  0.186110
# horsepower        ...    0.809769         NaN   0.573677  0.080940
# peakrpm           ...   -0.244660         NaN  -0.254976 -0.067964
# citympg           ...   -0.653658         NaN  -0.584532 -0.042145
# highwaympg        ...   -0.677470         NaN  -0.587012 -0.043931
# price             ...    0.874145         NaN   0.553173  0.079443
#
#                   compressionratio  horsepower   peakrpm   citympg  \
# car_ID                    0.150276   -0.015006 -0.203789  0.015940
# symboling                -0.178515    0.070873  0.273606 -0.035823
# CarName                        NaN         NaN       NaN       NaN
# fueltype                       NaN         NaN       NaN       NaN
# aspiration                     NaN         NaN       NaN       NaN
# doornumber                     NaN         NaN       NaN       NaN
# carbody                        NaN         NaN       NaN       NaN
# drivewheel                     NaN         NaN       NaN       NaN
# enginelocation                 NaN         NaN       NaN       NaN
# wheelbase                 0.249786    0.353294 -0.360469 -0.470414
# carlength                 0.158414    0.552623 -0.287242 -0.670909
# carwidth                  0.181129    0.640732 -0.220012 -0.642704
# carheight                 0.261214   -0.108802 -0.320411 -0.048640
# curbweight                0.151362    0.750739 -0.266243 -0.757414
# enginetype                     NaN         NaN       NaN       NaN
# cylindernumber                 NaN         NaN       NaN       NaN
# enginesize                0.028971    0.809769 -0.244660 -0.653658
# fuelsystem                     NaN         NaN       NaN       NaN
# boreratio                 0.005197    0.573677 -0.254976 -0.584532
# stroke                    0.186110    0.080940 -0.067964 -0.042145
# compressionratio          1.000000   -0.204326 -0.435741  0.324701
# horsepower               -0.204326    1.000000  0.131073 -0.801456
# peakrpm                  -0.435741    0.131073  1.000000 -0.113544
# citympg                   0.324701   -0.801456 -0.113544  1.000000
# highwaympg                0.265201   -0.770544 -0.054275  0.971337
# price                     0.067984    0.808139 -0.085267 -0.685751
#
#                   highwaympg     price
# car_ID              0.011255 -0.109093
# symboling           0.034606 -0.079978
# CarName                  NaN       NaN
# fueltype                 NaN       NaN
# aspiration               NaN       NaN
# doornumber               NaN       NaN
# carbody                  NaN       NaN
# drivewheel               NaN       NaN
# enginelocation           NaN       NaN
# wheelbase          -0.544082  0.577816
# carlength          -0.704662  0.682920
# carwidth           -0.677218  0.759325
# carheight          -0.107358  0.119336
# curbweight         -0.797465  0.835305
# enginetype               NaN       NaN
# cylindernumber           NaN       NaN
# enginesize         -0.677470  0.874145
# fuelsystem               NaN       NaN
# boreratio          -0.587012  0.553173
# stroke             -0.043931  0.079443
# compressionratio    0.265201  0.067984
# horsepower         -0.770544  0.808139
# peakrpm            -0.054275 -0.085267
# citympg             0.971337 -0.685751
# highwaympg          1.000000 -0.697599
# price              -0.697599  1.000000
#
# [26 rows x 26 columns]

# %%
plt.figure(figsize=(15,15))
corr=df.corr()
cmap=matplotlib.colors.LinearSegmentedColormap.from_list("custom",["#00aabb","#ffffff","#ff7777"])
sns.heatmap(corr,cmap=cmap,annot=True)
plt.show()

# %%
df=df[["symboling","wheelbase","carlength","carwidth",	"carheight",	"curbweight",	"enginesize",	"boreratio",	"stroke",	"compressionratio",	"horsepower",	"peakrpm",	"citympg",	"highwaympg",	"price"]]
x=np.array(df.drop('price',axis=1))
y=np.array(df['price'])

xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.2)

# %%
scaler=MinMaxScaler()
xtrain=scaler.fit_transform(xtrain)
xtest=scaler.transform(xtest)

# %%
model=DecisionTreeRegressor()
model.fit(xtrain,ytrain)
predictions=model.predict(xtest)

# %%
print(f"Accuracy     :{model.score(xtest,predictions) * 100}")
print(f"R Squared Error   :{round(metrics.r2_score(ytest,predictions) * 100,2)}")
print(f"Mean Absolute Error  :{metrics.mean_absolute_error(ytest,predictions)}")
print(f"Mean Squared Error  :{metrics.mean_squared_error(ytest,predictions)}")
print(f"Root Mean Square Error  :{np.sqrt(metrics.mean_squared_error(ytest,predictions))}")
# Out:
# Accuracy     :100.0
# R Squared Error   :89.22
# Mean Absolute Error  :1840.1666585365854
# Mean Squared Error  :7074056.687021683
# Root Mean Square Error  :2659.709887754994

# %%
plt.scatter(ytest,predictions)
plt.xlabel("Actual Price")
plt.ylabel("Predicted Price")
plt.title("actual price vs predicted price")
plt.show()

# %%
def prediction(input_data):
  car_data=df.drop('price',axis=1).iloc[input_data]
  car_scaler=scaler.transform(car_data.values.reshape(-1,14))
  prediction=model.predict(car_scaler)
  print(f"predicted price of this car is :{prediction[0]}")

  print()

  real_price=df.iloc[input_data].price
  print(f"Real price of car is       :{real_price}")

prediction(12)
# Out:
# predicted price of this car is :20970.0
#
# Real price of car is       :20970.0
